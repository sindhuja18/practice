# %%
import MySQLdb
import requests
import time
from bs4 import BeautifulSoup
import bs4
from selenium import webdriver
import re

# %%
def get_browser():
    browser = None
    browser = webdriver.PhantomJS(executable_path='/usr/local/bin/phantomjs')
    browser.set_page_load_timeout(60)
    return browser

# %%
url = "https://paytm.com/shop/p/apple-iphone-4s-16-gb-white-MOBAPPLE-IPHONESUPE65582AAF11DE1"

# %%
browser = get_browser()

# %%
page = browser.get(url)
soup = BeautifulSoup(browser.page_source,'html.parser')

# %%
print soup
# Out:
# <!DOCTYPE html>
# ...

# %%
price = soup.find('meta', {"itemprop":"price"}).find_previous_sibling()
print price
# Out:
# <span ng-if="!product.product.isOnlyCarCategory">Buy for Rs.14,999</span>

# %%
prices = re.findall('[0-9,]+', status.text)
print prices
# Out:
# [u'14,999']

# %%
float(prices[0].replace(',','')) if prices else None
# Out:
# 14999.0

# %%
status = soup.find('span', {"class":"red"}).text
print status
# Out:
# Out of stock

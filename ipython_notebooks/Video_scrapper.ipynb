# %%
import pandas as pd
import re
from video_scraper import video_scraper

# %%
video = pd.read_csv('US_smartphones2_injestion - Sheet16.csv')

# %%
video_list = [[str(x['id']), x['product_name']] for x in video.to_dict('records')]

# %%
video_scraper(video_list)
# Out:
# ['1', 'Apple iPhone 4']
# ['2', 'Apple iPhone 4S']
# ['3', 'Apple iPhone 5']
# ['4', 'Apple iPhone 5C']
# ['5', 'Apple iPhone 5S']
# ['6', 'Apple iPhone 6']
# ['7', 'Apple iPhone 6 Plus']
# ['8', 'Asus Zenfone 5 A501CG']
# ['9', 'Asus Zenfone 6 A600CG / A601CG']
# ['10', 'BlackBerry Bold 9900']
# ['11', 'BlackBerry Curve 3G 9300']
# ['12', 'Blackberry Curve 9320']
# ['13', 'BlackBerry Curve 9360']
# ['14', 'BlackBerry Passport']
# ['15', 'BlackBerry Q10']
# ['16', 'BlackBerry Q5']
# ['17', 'BlackBerry Torch 9810']
# ['18', 'BlackBerry Torch 9860']
# ['19', 'BlackBerry Z10']
# ['20', 'BlackBerry Z30']
# ['21', 'Google Nexus 4']
# ['22', 'Google Nexus 5']
# ['23', 'Google Nexus 6']
# ['24', 'HTC One 802d']
# ['25', 'HTC One M8']
# ['26', 'HTC ONE X S720E']
# ['27', 'Huawei Ascend P6']
# ['28', 'Huawei Ascend P7']
# ['29', 'Huawei Honor 3C']
# ['30', 'Lenovo A850']
# ['31', 'Lenovo S930']
# ['32', 'LG G-Flex']
# ['33', 'LG G2']
# ['34', 'LG G2 D802T']
# ['35', 'LG G3 D855']
# ...

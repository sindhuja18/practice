# %%
import urllib2
from bs4 import BeautifulSoup
import bs4

# %%
opener = urllib2.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]

# %%
url = "https://paytm.com/shop/p/samsung-a5-2016-edition-white-MOBSAMSUNG-A5-2FLAS266179BD51305E"

# %%
page = opener.open(url)
soup = BeautifulSoup(page.read(),'html.parser')

# %%
print soup
# Out:
# <!DOCTYPE html>
# <html class="ready" id="ng-app" lang="en" xmlns:ng="http://angularjs.org"><head><style>[ng\:cloak],[ng-cloak],[data-ng-cloak],[x-ng-cloak],.ng-cloak,.x-ng-cloak,.ng-hide{display:none !important;}ng\:form{display:block;}html{background:url("data:image/png;base64,...") no-repeat !important;background-position: 50% 150px !important;display:block;position : relative !important;width: 235px ;margin: auto !important;height: 97px ;margin-top: 15%;  background-color: #f5f8f9  !important;}html:after{content:"Paytm is loading...";position: absolute !important;top:200px !important;color: #555 !important;font-family: 'Open Sans' , sans-serif !important;font-size: 25px !important;font-weight: bold !important;margin-left:6px !important  ;     }</style><meta content="text/html; charset=utf-8" http-equiv="Content-Type"><meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"><meta content="no-cache" http-equiv="Pragma"><meta content="0" http-equiv="Expires"><meta content="578fa68d1988f66b6eeb98681b6646ae" name="p:domain_verify"><meta content="!" name="fragment"><link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.3.0/css/font-awesome.min.css" rel="stylesheet" type="text/css"><meta content="width=device-width, initial-scale=1" name="viewport"><meta content="{{value}}" name="{{key}}" ng-repeat="(key,value) in metaTags"><meta content="{{value}}" name="{{key}}" ng-repeat="(key,value) in ogTags" property="{{key.replace('_', ':')}}"><meta content="{{metaTagsFollowNoFollow.no_index}},{{metaTagsFollowNoFollow.no_follow}}" name="ROBOTS"><link ng-href="{{canonicalPageUrl}}" rel="canonical"><link href="/opensearch.xml" rel="search" type="application/opensearchdescription+xml"><title ng-bind="pageTitle">Online Mobile Recharge - Postpaid, DTH &amp; Datacard Bill Payments at Paytm.com</title><script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyAprVto1qxh8ju4UlKJrRvB2Dhzif2hfqM&amp;v=3.21&amp;sensor=true"></script><script>if (window!= top)
#     var frame = top.document.getElementsByTagName("IFRAME");
#     if(typeof(frame) !== 'undefined' && frame[0].id !== 'document')
#       top.location.href=location.href
# window.urlMapper = {};
# window.urlParams = {};
# window.referral = false;
#
#
# </script><link href="https://shop.paytm.com/min/css/827868c41515947cd07edd5762a15e06.css" rel="stylesheet" type="text/css"><script type="text/javascript">var branchMetricData = '';
# window.BranchInit = function BranchInit(testcallback) {
#
#   var config = {
#     app_id: '46886721278706641',
#     debug: true,
#     init_callback: testcallback ? testcallback : function(){
#       branchMetricData = JSON.stringify(branch.utils.readSession())
#       localStorage.bmetricReferral = true
#     }
#   };
#   // Begin Branch SDK //
#   var Branch_Init=function(a){self=this,self.app_id=a.app_id,self.debug=a.debug,self.init_callback=a.init_callback,self
#   .queued=[],this.init=function(){for(var a=["close","logout","track","identify","createLink","showReferrals","showCredits",
#   "redeemCredits","appBanner"],b=0;b<a.length;b++)self[a[b]]=function(a){return function(){self.queued.push([a].concat(Array
#   .prototype.slice.call(arguments,0)))}}(a[b])},self.init();var b=document.createElement("script");b.type="text/javascript",
#   b.async=!0,b.src="https://bnc.lt/_r",document.getElementsByTagName("head")[0].appendChild(b),self._r=function(){if(
#   void 0!==window.browser_fingerprint_id){var a=document.createElement("script");a.type="text/javascript",a.async=!0,a
#   .src="https://s3-us-west-1.amazonaws.com/branch-web-sdk/branch-0.x.min.js",document.getElementsByTagName("head")[0].appendChild(a)
#   }else window.setTimeout("self._r()",100)},self._r()};window.branch=new Branch_Init(config);
#   // End Branch SDK //
# };
#
# if (window.referral) {
#   window.BranchInit();
# }</script></link></link></link></meta></meta></meta></meta></link></meta></meta></meta></meta></meta></meta></head><script src="https://shop.paytm.com/min/js/0e1deed5f8ed38d1ffd5116574f16ac0.js"></script><body id="body" ng-class="isBodyBackGround ? '' : ''" ng-cloak="" ng-controller="paytmCtrl as paytm"><script>var GTM_KEY = {"host":"https://paytm.com","apihost":"https://paytm.com/shop","cart":"https://cart.paytm.com","apiproxy":"https://apiproxy.paytm.com","cart_internal":"http://cartelb.mkt.paytm","catalog":"https://catalog.paytm.com","catalog_internal":"http://catalogelb.mkt.paytm","resourceurl":"https://shop.paytm.com","notification":"https://notification.paytm.com","ffhost":"https://fulfillment.paytm.com","pg":"https://secure.paytm.in","tickets":"https://tickets.paytm.com","search":"https://search.paytm.com","assetscdn":"https://assetscdn.paytm.com","site":"https://sites.paytm.com/site","oToOConfig":"https://apiproxy.paytm.com","oauthurl":"https://accounts.paytm.com","track":{"GTM_KEY":"GTM-PTT2P2","GA_KEY":"UA-36768858-4"}} ? ({"host":"https://paytm.com","apihost":"https://paytm.com/shop","cart":"https://cart.paytm.com","apiproxy":"https://apiproxy.paytm.com","cart_internal":"http://cartelb.mkt.paytm","catalog":"https://catalog.paytm.com","catalog_internal":"http://catalogelb.mkt.paytm","resourceurl":"https://shop.paytm.com","notification":"https://notification.paytm.com","ffhost":"https://fulfillment.paytm.com","pg":"https://secure.paytm.in","tickets":"https://tickets.paytm.com","search":"https://search.paytm.com","assetscdn":"https://assetscdn.paytm.com","site":"https://sites.paytm.com/site","oToOConfig":"https://apiproxy.paytm.com","oauthurl":"https://accounts.paytm.com","track":{"GTM_KEY":"GTM-PTT2P2","GA_KEY":"UA-36768858-4"}}.track ? {"host":"https://paytm.com","apihost":"https://paytm.com/shop","cart":"https://cart.paytm.com","apiproxy":"https://apiproxy.paytm.com","cart_internal":"http://cartelb.mkt.paytm","catalog":"https://catalog.paytm.com","catalog_internal":"http://catalogelb.mkt.paytm","resourceurl":"https://shop.paytm.com","notification":"https://notification.paytm.com","ffhost":"https://fulfillment.paytm.com","pg":"https://secure.paytm.in","tickets":"https://tickets.paytm.com","search":"https://search.paytm.com","assetscdn":"https://assetscdn.paytm.com","site":"https://sites.paytm.com/site","oToOConfig":"https://apiproxy.paytm.com","oauthurl":"https://accounts.paytm.com","track":{"GTM_KEY":"GTM-PTT2P2","GA_KEY":"UA-36768858-4"}}.track.GTM_KEY : 'GTM-TKV6G6') : 'GTM-TKV6G6';
# (function(w,d,s,l,i){
#   w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#   var f=d.getElementsByTagName('body')[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#   j.async=true;j.src= '//www.googletagmanager.com/gtm.js?id='+i+dl;f.appendChild(j);
# })(window,document,'script','dataLayer', GTM_KEY);</script><script src="https://shop.paytm.com/min/js/467df9bc25f1a0321b281e4fef416c19.js"></script><div id="fb-root"></div><div ng-show="paytm.usingOldBrowser">{{paytm.usingOldBrowserText}}</div><div id="site-wrapper" ng-class="paytm.newHeader || paytm.newMainHeader || paytm.newSummaryHeader ? 'newsite' : ''" ng-show="!paytm.usingOldBrowser"><div ng-if="!paytm.moviePageHeader"><div class="dummy-box" id="main-header"></div></div><div ng-show="!paytm.moviePageHeader"><!--<Created>by akshaybindal on 18/2/16.</Created>--><div class="actual-box" id="main-header" ng-class='{"borderLine" : hideNewTabs}' scroller=""><div class="blue-bar" ng-class='{"fadeIN" : !showfixedHeader,"fadeOUT" : showfixedHeader}'><div class="addheader-overlay" ng-if="paytm.youtubeVideoSrc"><div class="w-675"><div class="fl frame"><iframe allowfullscreen="" frameborder="0" height="200" ng-src="{{paytm.youtubeVideoSrc}}" width="360"></iframe></div><div class="text"><div class="Ttext">{{paytm.youtubeItem.display_text}}</div><div class="Btext">#PaytmKaro</div><a class="facebook-but" item="paytm.youtubeItem" paytm-facebook-add-sharing=""></a><a class="tweet-but" item="paytm.youtubeItem" twitter-add-sharing=""></a></div></div><div class="closeVideo" ng-click="paytm.hideYoutubeOverlay()"><a class="icon-Delete"></a></div></div><div class="container"><div class="fl"><top-header-dynamic alignment="left"></top-header-dynamic></div><div class="fr"><top-header-dynamic alignment="right"></top-header-dynamic></div></div><div class="clear"></div></div><div id="user-detail"><div class="container"><div hamburger-menu=""></div><div class="paytmLogo"><a href="/" ng-click="paytm.sendPaytmLogoTracking()"><span class="icon-logo-Colored"><span class="path1"></span><span class="path2"></span><span class="path3"></span><span class="path4"></span><span class="path5"></span></span></a></div><div class="searchBox"><md-input-container id="for-search" loop-items="" ng-class='{"open": searchOpened}' ng-controller="searchCtrl" ng-hide="onCheckoutPage"><label>Search for a Product , Brand or Category</label><input aria-invalid="false" focus-me="{{focusedMe}}" maxlength="255" ng-focus="getTrendingSearches()" ng-keyup="suggestSearch($event.keyCode)" ng-model="searchAcrossApp" placeholder="" tabindex="0" type="text"><i class="icon-homeSearch" ng-click="searchOpened = !searchOpened"></i><i class="fa fa-times" ng-click='searchAcrossApp = ""' ng-show="searchOpened &amp;&amp; searchAcrossApp"></i><div id="suggested-search" ng-show="haveResults &amp;&amp; (!searchAcrossApp || searchAcrossApp.length &lt;= 2)" tabindex="0"><ul><div class="popProd blue" ng-show="recentSearches.length &gt; 0">Recent Searches</div><li ng-repeat="recentSearch in recentSearches track by $index"><a id="search-t-item" ng-click="updateSearchQuery(recentSearch, true)"><span class="highlightSearch" ng-bind-html="highlight(recentSearch, searchAcrossApp)"></span></a></li></ul><ul><div class="popProd blue" ng-show="popularSearchResults.keywords.length &gt; 0">Popular Searches</div><li ng-repeat="keyword in popularSearchResults.keywords"><a id="search-t-item" ng-click="updateSearchQuery(keyword.text)"><span class="highlightSearch" ng-bind-html="highlight(keyword.text, searchAcrossApp)"></span></a></li></ul><ul><li ng-if="recentSearches.length"><div class="popProd fr blue" ng-click="removeRecentSearches()">Remove Search History</div></li></ul></div><div id="suggested-search" ng-show="haveResults &amp;&amp; searchAcrossApp.length &gt; 2" tabindex="0"><ul><li ng-repeat="keyword in suggestedSearchResults.keywords"><a id="search-t-item" ng-click="updateSearchQuery(keyword.text)"><span class="highlightSearch" ng-bind-html="highlight(keyword.text, searchAcrossApp)"></span><span ng-if="keyword.count">about<strong> {{::keyword.count}}</strong> results</span></a><ul><li ng-if="keyword.cats.length">in<a flat-repeat="" from="child" ng-click="resetSearch()" ng-href="/@{{cat.brandStoreName }}{{:: ur ...
#     angular.bootstrap(document.documentElement, ['PaytmApp']);
# });
# angular.module('paytmApp.Constants', []).constant('Constants', {
#     viewConfig: '{"host":"https://paytm.com","apihost":"https://paytm.com/shop","cart":"https://cart.paytm.com","apiproxy":"https://apiproxy.paytm.com","cart_internal":"http://cartelb.mkt.paytm","catalog":"https://catalog.paytm.com","catalog_internal":"http://catalogelb.mkt.paytm","resourceurl":"https://shop.paytm.com","notification":"https://notification.paytm.com","ffhost":"https://fulfillment.paytm.com","pg":"https://secure.paytm.in","tickets":"https://tickets.paytm.com","search":"https://search.paytm.com","assetscdn":"https://assetscdn.paytm.com","site":"https://sites.paytm.com/site","oToOConfig":"https://apiproxy.paytm.com","oauthurl":"https://accounts.paytm.com","track":{"GTM_KEY":"GTM-PTT2P2","GA_KEY":"UA-36768858-4"}}',
#     source: 'web',
#     order: '',
#     viewConfig1: '{}',
#     session : '{"isLogin":false,"env":"production"}',
#     host : '',
#     isRenderBox: '',
#     buildNumber: ''
# });
#
# // Answers Cloud Services Embed Script v1.02
# // DO NOT MODIFY BELOW THIS LINE *****************************************
# ;(function (g) {
# var d = document, i, am = d.createElement('script'), h = d.head || d.getElementsByTagName("head")[0],
# aex = {"src": "//gateway.answerscloud.com/paytm-in-en/production/gateway.min.js", "type": "text/javascript", "async": "true", "data-vendor": "acs","data-role": "gateway"};
# for (var attr in aex) { am.setAttribute(attr,aex[attr]); }
# h.appendChild(am);
# g['acsReady'] = function (h) {var aT = '__acsReady__', args = Array.prototype.slice.call(arguments, 0),k = setInterval(function () {if (typeof g[aT] === 'function') {clearInterval(k);for (i = 0; i < args.length; i++) {g[aT].call(g, function(fn) { return function() { setTimeout(fn, 1) };}(args[i]));}}}, 50);};
# })(window);</script><span paytm-home-schema-tag=""></span></body></html>

# %%
prices = soup.find('span', attrs={"class":"buy-bar"})

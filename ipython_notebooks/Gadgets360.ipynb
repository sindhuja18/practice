# %%
import MySQLdb
import requests
import time
from bs4 import BeautifulSoup
import bs4
from selenium import webdriver

# %%
def get_browser():
    browser = None

#     if source_id == 12:
#         proxy = select_random_proxy(proxies_sf)
#         service_args = [ '--proxy={}'.format(proxy), '--proxy-type=socks5']
    browser = webdriver.PhantomJS(executable_path='/usr/local/bin/phantomjs')
    browser.set_page_load_timeout(60)
    return browser

# %%
url = 'https://gadgets360.com/shop/samsung-galaxy-j1-white-4-gb-33362d3938'

# %%
page = requests.get(url)
soup = BeautifulSoup(page.text,'html.parser')
prices = soup.find('span', attrs={"class":"selling_price"})

# %%
print prices
# Out:
# <span class="selling_price red_txt margin_t5"><span class="rupee">Rs.</span>6,542 <span class="discount">(22%) off</span> </span>

# %%
strings = [x for x in prices if isinstance(x, (bs4.element.NavigableString)) and x.strip()]
if strings[0]:
    price = float(strings[0].replace(',',''))

# %%
print price
# Out:
# 6542.0

# %%
status = soup.find('span', {"id":"statusAddToCart"})
status
# Out:
# <span class="bold_txt addtocart_status_msg margin_t15" id="statusAddToCart"></span>

# %%
browser = get_browser()

# %%
browser.get(url)

# %%
b_soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
status = b_soup.find('span', {"id":"statusAddToCart"}).strong.text.__str__()

# %%
b_soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type">
# <title>Samsung Galaxy J1 White, 4 GB Price in India – Buy Samsung Galaxy J1 White, 4 GB Mobiles Online </title>
# <meta content="width=1280" name="viewport">
# <link href="https://ndtvgadgets.cashify.in/css/widget/snapdeal/reglobe_widget.css?v=11" rel="stylesheet" type="text/css"><link href="https://gadgets360.com/shop/static//images/favicon.ico" rel="shortcut icon">
# <link href="https://gadgets360.com/shop/static//images/gadgets360_57x57.png" rel="apple-touch-icon" sizes="57x57">
# <link href="https://gadgets360.com/shop/static//images/gadgets360_72x72.png" rel="apple-touch-icon" sizes="72x72">
# <link href="https://gadgets360.com/shop/static//images/gadgets360_114x114.png" rel="apple-touch-icon" sizes="114x114">
# <link href="https://gadgets360.com/shop/static//images/gadgets360_144x144.png" rel="apple-touch-icon" sizes="144x144">
# ...

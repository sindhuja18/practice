# %%
import MySQLdb
import requests
import time
from bs4 import BeautifulSoup
import bs4
import pandas as pd
from scrape import device_specs_built_in_scraper

# %%
source_maps = pd.read_csv('final_product_list - Sheet4.csv')

# %%
source_maps_lists = [[x['buysmaart_id'], x['devicespec_id'], x['url']] for x in source_maps.to_dict('records')]

# %%
source_maps_lists
# Out:
# [[209,
#   'model_d6073572',
#   'http://www.devicespecifications.com/en/model/d6073572'],
#  [210,
#   'model_0f7b37aa',
#   'http://www.devicespecifications.com/en/model/0f7b37aa'],
#  [211,
#   'model_327332e2',
#   'http://www.devicespecifications.com/en/model/327332e2'],
#  [212,
#   'model_537436fd',
#   'http://www.devicespecifications.com/en/model/537436fd'],
#  [213,
#   'model_ff1536fb',
#   'http://www.devicespecifications.com/en/model/ff1536fb'],
#  [214,
#   'model_da1133db',
#   'http://www.devicespecifications.com/en/model/da1133db'],
#  [215,
#   'model_745f36f8',
#   'http://www.devicespecifications.com/en/model/745f36f8'],
#  [216,
#   'model_ae1e345d',
#   'http://www.devicespecifications.com/en/model/ae1e345d'],
#  [217,
#   'model_69aa3ab9',
#   'http://www.devicespecifications.com/en/model/69aa3ab9'],
#  [218,
#   'model_53053472',
#   'http://www.devicespecifications.com/en/model/53053472'],
#  [219,
#   'model_ca88375b',
# ...

# %%
device_specs_built_in_scraper(source_maps_lists)
# Out:
# 8 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 8 GB
# indexError
# 4 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 8 GB
# indexError
# 512 MB
# indexError
# 512 MB
# indexError
# 4 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 8 GB
# indexError
# 64 GB
# indexError
# 4 GB
# indexError
# 4 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 4 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 4 GB
# indexError
# 8 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 16 GB
# indexError
# 4 GB
# indexError
# 16 GB
# indexError
# 16 GB
# ...
